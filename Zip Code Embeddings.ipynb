# %%
import numpy as np
import pandas as pd

import tensorflow as tf

from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# define documents
data = pd.read_csv('data\ZIP_TRACT_122021.csv',dtype={
                     'zip': str,
                     'tract': str,
                     'usps_zip_pref_city': str,
                     'usps_zip_pref_state': str,
                     'res_ratio': float,
                     'bus_ratio': float,
                     'oth_ratio': float,
                     'tot_ratio': float})

# %%
data = data.drop(['res_ratio', 'bus_ratio', 'oth_ratio'], axis=1)
docs = data[['zip', 'tract',  'usps_zip_pref_city', 'usps_zip_pref_state']].apply(lambda x: ' '.join(x), axis=1)
labels = data['tot_ratio']

# %%
# integer encode the documents
vocab_size = 131322
# create the tokenizer
t = Tokenizer()
# fit the tokenizer on the documents
t.fit_on_texts(docs)

# %%
encoded_docs = t.texts_to_sequences(docs)

# %%
# pad documents to a max length of 4 words
max_length = 4
padded_docs = pad_sequences(encoded_docs, maxlen=max_length, padding='post')

# %%
# define the model
model = Sequential()
model.add(Embedding(vocab_size, 8, input_length=max_length))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))
# compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# summarize the model
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 4, 8)              1050576
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 10)                330
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,050,917
# Trainable params: 1,050,917
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# fit the model
model.fit(padded_docs, labels, epochs=250, verbose=2)
# Out:
# Epoch 1/250
# 5381/5381 - 22s - loss: 0.0881 - 22s/epoch - 4ms/step
# Epoch 2/250
# 5381/5381 - 21s - loss: 0.0600 - 21s/epoch - 4ms/step
# Epoch 3/250
# 5381/5381 - 21s - loss: 0.0450 - 21s/epoch - 4ms/step
# Epoch 4/250
# 5381/5381 - 21s - loss: 0.0371 - 21s/epoch - 4ms/step
# Epoch 5/250
# 5381/5381 - 21s - loss: 0.0309 - 21s/epoch - 4ms/step
# Epoch 6/250
# 5381/5381 - 21s - loss: 0.0258 - 21s/epoch - 4ms/step
# Epoch 7/250
# 5381/5381 - 21s - loss: 0.0221 - 21s/epoch - 4ms/step
# Epoch 8/250
# 5381/5381 - 21s - loss: 0.0192 - 21s/epoch - 4ms/step
# Epoch 9/250
# 5381/5381 - 22s - loss: 0.0171 - 22s/epoch - 4ms/step
# Epoch 10/250
# 5381/5381 - 21s - loss: 0.0156 - 21s/epoch - 4ms/step
# Epoch 11/250
# 5381/5381 - 21s - loss: 0.0144 - 21s/epoch - 4ms/step
# Epoch 12/250
# 5381/5381 - 21s - loss: 0.0135 - 21s/epoch - 4ms/step
# Epoch 13/250
# 5381/5381 - 21s - loss: 0.0127 - 21s/epoch - 4ms/step
# Epoch 14/250
# 5381/5381 - 21s - loss: 0.0121 - 21s/epoch - 4ms/step
# Epoch 15/250
# 5381/5381 - 21s - loss: 0.0116 - 21s/epoch - 4ms/step
# Epoch 16/250
# 5381/5381 - 21s - loss: 0.0111 - 21s/epoch - 4ms/step
# Epoch 17/250
# 5381/5381 - 22s - loss: 0.0107 - 22s/epoch - 4ms/step
# Epoch 18/250
# 5381/5381 - 21s - loss: 0.0104 - 21s/epoch - 4ms/step
# Epoch 19/250
# 5381/5381 - 21s - loss: 0.0101 - 21s/epoch - 4ms/step
# Epoch 20/250
# 5381/5381 - 21s - loss: 0.0098 - 21s/epoch - 4ms/step
# Epoch 21/250
# 5381/5381 - 21s - loss: 0.0096 - 21s/epoch - 4ms/step
# Epoch 22/250
# 5381/5381 - 21s - loss: 0.0093 - 21s/epoch - 4ms/step
# Epoch 23/250
# 5381/5381 - 21s - loss: 0.0091 - 21s/epoch - 4ms/step
# Epoch 24/250
# 5381/5381 - 21s - loss: 0.0090 - 21s/epoch - 4ms/step
# Epoch 25/250
# 5381/5381 - 21s - loss: 0.0087 - 21s/epoch - 4ms/step
# Epoch 26/250
# 5381/5381 - 21s - loss: 0.0086 - 21s/epoch - 4ms/step
# Epoch 27/250
# 5381/5381 - 21s - loss: 0.0085 - 21s/epoch - 4ms/step
# Epoch 28/250
# 5381/5381 - 25s - loss: 0.0083 - 25s/epoch - 5ms/step
# Epoch 29/250
# 5381/5381 - 26s - loss: 0.0082 - 26s/epoch - 5ms/step
# Epoch 30/250
# 5381/5381 - 21s - loss: 0.0081 - 21s/epoch - 4ms/step
# Epoch 31/250
# 5381/5381 - 21s - loss: 0.0080 - 21s/epoch - 4ms/step
# Epoch 32/250
# 5381/5381 - 24s - loss: 0.0079 - 24s/epoch - 4ms/step
# Epoch 33/250
# 5381/5381 - 24s - loss: 0.0078 - 24s/epoch - 4ms/step
# Epoch 34/250
# 5381/5381 - 23s - loss: 0.0077 - 23s/epoch - 4ms/step
# Epoch 35/250
# 5381/5381 - 23s - loss: 0.0076 - 23s/epoch - 4ms/step
# Epoch 36/250
# 5381/5381 - 24s - loss: 0.0075 - 24s/epoch - 4ms/step
# Epoch 37/250
# 5381/5381 - 23s - loss: 0.0074 - 23s/epoch - 4ms/step
# Epoch 38/250
# 5381/5381 - 21s - loss: 0.0074 - 21s/epoch - 4ms/step
# Epoch 39/250
# 5381/5381 - 21s - loss: 0.0073 - 21s/epoch - 4ms/step
# Epoch 40/250
# 5381/5381 - 21s - loss: 0.0073 - 21s/epoch - 4ms/step
# Epoch 41/250
# 5381/5381 - 21s - loss: 0.0072 - 21s/epoch - 4ms/step
# Epoch 42/250
# 5381/5381 - 23s - loss: 0.0071 - 23s/epoch - 4ms/step
# Epoch 43/250
# 5381/5381 - 25s - loss: 0.0071 - 25s/epoch - 5ms/step
# Epoch 44/250
# 5381/5381 - 24s - loss: 0.0070 - 24s/epoch - 4ms/step
# Epoch 45/250
# 5381/5381 - 23s - loss: 0.0069 - 23s/epoch - 4ms/step
# Epoch 46/250
# 5381/5381 - 23s - loss: 0.0069 - 23s/epoch - 4ms/step
# Epoch 47/250
# 5381/5381 - 23s - loss: 0.0069 - 23s/epoch - 4ms/step
# Epoch 48/250
# 5381/5381 - 23s - loss: 0.0068 - 23s/epoch - 4ms/step
# Epoch 49/250
# 5381/5381 - 22s - loss: 0.0067 - 22s/epoch - 4ms/step
# Epoch 50/250
# 5381/5381 - 22s - loss: 0.0067 - 22s/epoch - 4ms/step
# Epoch 51/250
# 5381/5381 - 21s - loss: 0.0066 - 21s/epoch - 4ms/step
# Epoch 52/250
# 5381/5381 - 21s - loss: 0.0066 - 21s/epoch - 4ms/step
# Epoch 53/250
# 5381/5381 - 21s - loss: 0.0066 - 21s/epoch - 4ms/step
# Epoch 54/250
# 5381/5381 - 22s - loss: 0.0065 - 22s/epoch - 4ms/step
# Epoch 55/250
# 5381/5381 - 25s - loss: 0.0065 - 25s/epoch - 5ms/step
# Epoch 56/250
# 5381/5381 - 25s - loss: 0.0065 - 25s/epoch - 5ms/step
# Epoch 57/250
# 5381/5381 - 24s - loss: 0.0064 - 24s/epoch - 4ms/step
# Epoch 58/250
# 5381/5381 - 24s - loss: 0.0064 - 24s/epoch - 4ms/step
# Epoch 59/250
# 5381/5381 - 23s - loss: 0.0064 - 23s/epoch - 4ms/step
# Epoch 60/250
# 5381/5381 - 24s - loss: 0.0063 - 24s/epoch - 4ms/step
# Epoch 61/250
# 5381/5381 - 23s - loss: 0.0063 - 23s/epoch - 4ms/step
# Epoch 62/250
# 5381/5381 - 23s - loss: 0.0063 - 23s/epoch - 4ms/step
# Epoch 63/250
# 5381/5381 - 23s - loss: 0.0062 - 23s/epoch - 4ms/step
# Epoch 64/250
# 5381/5381 - 21s - loss: 0.0062 - 21s/epoch - 4ms/step
# Epoch 65/250
# 5381/5381 - 21s - loss: 0.0062 - 21s/epoch - 4ms/step
# Epoch 66/250
# 5381/5381 - 22s - loss: 0.0062 - 22s/epoch - 4ms/step
# Epoch 67/250
# 5381/5381 - 23s - loss: 0.0061 - 23s/epoch - 4ms/step
# Epoch 68/250
# 5381/5381 - 23s - loss: 0.0061 - 23s/epoch - 4ms/step
# Epoch 69/250
# 5381/5381 - 24s - loss: 0.0061 - 24s/epoch - 4ms/step
# Epoch 70/250
# 5381/5381 - 26s - loss: 0.0061 - 26s/epoch - 5ms/step
# Epoch 71/250
# 5381/5381 - 27s - loss: 0.0060 - 27s/epoch - 5ms/step
# Epoch 72/250
# 5381/5381 - 23s - loss: 0.0060 - 23s/epoch - 4ms/step
# Epoch 73/250
# 5381/5381 - 24s - loss: 0.0060 - 24s/epoch - 4ms/step
# Epoch 74/250
# 5381/5381 - 23s - loss: 0.0060 - 23s/epoch - 4ms/step
# Epoch 75/250
# 5381/5381 - 23s - loss: 0.0060 - 23s/epoch - 4ms/step
# Epoch 76/250
# 5381/5381 - 23s - loss: 0.0060 - 23s/epoch - 4ms/step
# Epoch 77/250
# 5381/5381 - 24s - loss: 0.0059 - 24s/epoch - 4ms/step
# Epoch 78/250
# 5381/5381 - 28s - loss: 0.0059 - 28s/epoch - 5ms/step
# Epoch 79/250
# 5381/5381 - 24s - loss: 0.0059 - 24s/epoch - 4ms/step
# Epoch 80/250
# 5381/5381 - 25s - loss: 0.0059 - 25s/epoch - 5ms/step
# Epoch 81/250
# 5381/5381 - 24s - loss: 0.0059 - 24s/epoch - 4ms/step
# Epoch 82/250
# 5381/5381 - 23s - loss: 0.0058 - 23s/epoch - 4ms/step
# Epoch 83/250
# 5381/5381 - 25s - loss: 0.0058 - 25s/epoch - 5ms/step
# Epoch 84/250
# 5381/5381 - 24s - loss: 0.0058 - 24s/epoch - 4ms/step
# Epoch 85/250
# 5381/5381 - 24s - loss: 0.0058 - 24s/epoch - 5ms/step
# Epoch 86/250
# 5381/5381 - 25s - loss: 0.0058 - 25s/epoch - 5ms/step
# Epoch 87/250
# 5381/5381 - 25s - loss: 0.0058 - 25s/epoch - 5ms/step
# Epoch 88/250
# 5381/5381 - 25s - loss: 0.0057 - 25s/epoch - 5ms/step
# Epoch 89/250
# 5381/5381 - 24s - loss: 0.0057 - 24s/epoch - 5ms/step
# Epoch 90/250
# 5381/5381 - 25s - loss: 0.0057 - 25s/epoch - 5ms/step
# Epoch 91/250
# 5381/5381 - 25s - loss: 0.0057 - 25s/epoch - 5ms/step
# Epoch 92/250
# 5381/5381 - 24s - loss: 0.0057 - 24s/epoch - 4ms/step
# Epoch 93/250
# 5381/5381 - 25s - loss: 0.0057 - 25s/epoch - 5ms/step
# Epoch 94/250
# 5381/5381 - 24s - loss: 0.0057 - 24s/epoch - 5ms/step
# Epoch 95/250
# 5381/5381 - 24s - loss: 0.0056 - 24s/epoch - 5ms/step
# Epoch 96/250
# 5381/5381 - 24s - loss: 0.0056 - 24s/epoch - 4ms/step
# Epoch 97/250
# 5381/5381 - 24s - loss: 0.0056 - 24s/epoch - 4ms/step
# Epoch 98/250
# 5381/5381 - 25s - loss: 0.0056 - 25s/epoch - 5ms/step
# Epoch 99/250
# 5381/5381 - 24s - loss: 0.0056 - 24s/epoch - 5ms/step
# Epoch 100/250
# 5381/5381 - 23s - loss: 0.0056 - 23s/epoch - 4ms/step
# Epoch 101/250
# 5381/5381 - 24s - loss: 0.0056 - 24s/epoch - 4ms/step
# Epoch 102/250
# 5381/5381 - 23s - loss: 0.0056 - 23s/epoch - 4ms/step
# Epoch 103/250
# 5381/5381 - 23s - loss: 0.0056 - 23s/epoch - 4ms/step
# Epoch 104/250
# 5381/5381 - 23s - loss: 0.0055 - 23s/epoch - 4ms/step
# Epoch 105/250
# 5381/5381 - 23s - loss: 0.0055 - 23s/epoch - 4ms/step
# Epoch 106/250
# 5381/5381 - 24s - loss: 0.0055 - 24s/epoch - 5ms/step
# Epoch 107/250
# 5381/5381 - 23s - loss: 0.0055 - 23s/epoch - 4ms/step
# Epoch 108/250
# 5381/5381 - 25s - loss: 0.0055 - 25s/epoch - 5ms/step
# Epoch 109/250
# 5381/5381 - 25s - loss: 0.0055 - 25s/epoch - 5ms/step
# Epoch 110/250
# 5381/5381 - 25s - loss: 0.0055 - 25s/epoch - 5ms/step
# Epoch 111/250
# 5381/5381 - 26s - loss: 0.0055 - 26s/epoch - 5ms/step
# Epoch 112/250
# 5381/5381 - 24s - loss: 0.0055 - 24s/epoch - 4ms/step
# Epoch 113/250
# 5381/5381 - 24s - loss: 0.0054 - 24s/epoch - 4ms/step
# Epoch 114/250
# 5381/5381 - 24s - loss: 0.0054 - 24s/epoch - 5ms/step
# Epoch 115/250
# 5381/5381 - 23s - loss: 0.0054 - 23s/epoch - 4ms/step
# Epoch 116/250
# 5381/5381 - 23s - loss: 0.0054 - 23s/epoch - 4ms/step
# Epoch 117/250
# 5381/5381 - 23s - loss: 0.0054 - 23s/epoch - 4ms/step
# Epoch 118/250
# 5381/5381 - 21s - loss: 0.0054 - 21s/epoch - 4ms/step
# Epoch 119/250
# 5381/5381 - 22s - loss: 0.0054 - 22s/epoch - 4ms/step
# Epoch 120/250
# 5381/5381 - 23s - loss: 0.0054 - 23s/epoch - 4ms/step
# Epoch 121/250
# 5381/5381 - 23s - loss: 0.0054 - 23s/epoch - 4ms/step
# Epoch 122/250
# 5381/5381 - 24s - loss: 0.0054 - 24s/epoch - 4ms/step
# Epoch 123/250
# 5381/5381 - 23s - loss: 0.0054 - 23s/epoch - 4ms/step
# Epoch 124/250
# 5381/5381 - 24s - loss: 0.0054 - 24s/epoch - 4ms/step
# Epoch 125/250
# 5381/5381 - 24s - loss: 0.0053 - 24s/epoch - 4ms/step
# Epoch 126/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 127/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 128/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 129/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 130/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 131/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 132/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 133/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 134/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 135/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 136/250
# 5381/5381 - 27s - loss: 0.0053 - 27s/epoch - 5ms/step
# Epoch 137/250
# 5381/5381 - 26s - loss: 0.0053 - 26s/epoch - 5ms/step
# Epoch 138/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 139/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 140/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 141/250
# 5381/5381 - 25s - loss: 0.0053 - 25s/epoch - 5ms/step
# Epoch 142/250
# 5381/5381 - 23s - loss: 0.0053 - 23s/epoch - 4ms/step
# Epoch 143/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 144/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 145/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 146/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 147/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 148/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 149/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 150/250
# 5381/5381 - 24s - loss: 0.0052 - 24s/epoch - 4ms/step
# Epoch 151/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 152/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 153/250
# 5381/5381 - 24s - loss: 0.0052 - 24s/epoch - 4ms/step
# Epoch 154/250
# 5381/5381 - 24s - loss: 0.0052 - 24s/epoch - 5ms/step
# Epoch 155/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 156/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 157/250
# 5381/5381 - 24s - loss: 0.0052 - 24s/epoch - 4ms/step
# Epoch 158/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 159/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 160/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 161/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 162/250
# 5381/5381 - 23s - loss: 0.0052 - 23s/epoch - 4ms/step
# Epoch 163/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 164/250
# 5381/5381 - 25s - loss: 0.0051 - 25s/epoch - 5ms/step
# Epoch 165/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 166/250
# 5381/5381 - 24s - loss: 0.0051 - 24s/epoch - 5ms/step
# Epoch 167/250
# 5381/5381 - 24s - loss: 0.0051 - 24s/epoch - 4ms/step
# Epoch 168/250
# 5381/5381 - 24s - loss: 0.0051 - 24s/epoch - 4ms/step
# Epoch 169/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 170/250
# 5381/5381 - 24s - loss: 0.0051 - 24s/epoch - 4ms/step
# Epoch 171/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 172/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 173/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 174/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 175/250
# 5381/5381 - 26s - loss: 0.0051 - 26s/epoch - 5ms/step
# Epoch 176/250
# 5381/5381 - 27s - loss: 0.0051 - 27s/epoch - 5ms/step
# Epoch 177/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 178/250
# 5381/5381 - 25s - loss: 0.0051 - 25s/epoch - 5ms/step
# Epoch 179/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 180/250
# 5381/5381 - 27s - loss: 0.0051 - 27s/epoch - 5ms/step
# Epoch 181/250
# 5381/5381 - 24s - loss: 0.0051 - 24s/epoch - 4ms/step
# Epoch 182/250
# 5381/5381 - 24s - loss: 0.0051 - 24s/epoch - 4ms/step
# Epoch 183/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 184/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 185/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 186/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 187/250
# 5381/5381 - 24s - loss: 0.0051 - 24s/epoch - 4ms/step
# Epoch 188/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 189/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 190/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 191/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 192/250
# 5381/5381 - 24s - loss: 0.0050 - 24s/epoch - 4ms/step
# Epoch 193/250
# 5381/5381 - 26s - loss: 0.0051 - 26s/epoch - 5ms/step
# Epoch 194/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 195/250
# 5381/5381 - 23s - loss: 0.0051 - 23s/epoch - 4ms/step
# Epoch 196/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 197/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 198/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 199/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 200/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 201/250
# 5381/5381 - 24s - loss: 0.0050 - 24s/epoch - 4ms/step
# Epoch 202/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 203/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 204/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 205/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 206/250
# 5381/5381 - 24s - loss: 0.0050 - 24s/epoch - 4ms/step
# Epoch 207/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 208/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 209/250
# 5381/5381 - 25s - loss: 0.0050 - 25s/epoch - 5ms/step
# Epoch 210/250
# 5381/5381 - 29s - loss: 0.0050 - 29s/epoch - 5ms/step
# Epoch 211/250
# 5381/5381 - 30s - loss: 0.0050 - 30s/epoch - 6ms/step
# Epoch 212/250
# 5381/5381 - 59s - loss: 0.0050 - 59s/epoch - 11ms/step
# Epoch 213/250
# 5381/5381 - 68s - loss: 0.0050 - 68s/epoch - 13ms/step
# Epoch 214/250
# 5381/5381 - 22s - loss: 0.0050 - 22s/epoch - 4ms/step
# Epoch 215/250
# 5381/5381 - 22s - loss: 0.0050 - 22s/epoch - 4ms/step
# Epoch 216/250
# 5381/5381 - 22s - loss: 0.0050 - 22s/epoch - 4ms/step
# Epoch 217/250
# 5381/5381 - 28s - loss: 0.0050 - 28s/epoch - 5ms/step
# Epoch 218/250
# 5381/5381 - 29s - loss: 0.0050 - 29s/epoch - 5ms/step
# Epoch 219/250
# 5381/5381 - 43s - loss: 0.0050 - 43s/epoch - 8ms/step
# Epoch 220/250
# 5381/5381 - 76s - loss: 0.0050 - 76s/epoch - 14ms/step
# Epoch 221/250
# 5381/5381 - 41s - loss: 0.0050 - 41s/epoch - 8ms/step
# Epoch 222/250
# 5381/5381 - 22s - loss: 0.0050 - 22s/epoch - 4ms/step
# Epoch 223/250
# 5381/5381 - 22s - loss: 0.0050 - 22s/epoch - 4ms/step
# Epoch 224/250
# 5381/5381 - 21s - loss: 0.0050 - 21s/epoch - 4ms/step
# Epoch 225/250
# 5381/5381 - 23s - loss: 0.0050 - 23s/epoch - 4ms/step
# Epoch 226/250
# 5381/5381 - 24s - loss: 0.0050 - 24s/epoch - 4ms/step
# Epoch 227/250
# 5381/5381 - 27s - loss: 0.0050 - 27s/epoch - 5ms/step
# Epoch 228/250
# 5381/5381 - 26s - loss: 0.0050 - 26s/epoch - 5ms/step
# Epoch 229/250
# 5381/5381 - 24s - loss: 0.0050 - 24s/epoch - 5ms/step
# Epoch 230/250
# 5381/5381 - 25s - loss: 0.0050 - 25s/epoch - 5ms/step
# Epoch 231/250
# 5381/5381 - 26s - loss: 0.0050 - 26s/epoch - 5ms/step
# Epoch 232/250
# 5381/5381 - 26s - loss: 0.0050 - 26s/epoch - 5ms/step
# Epoch 233/250
# 5381/5381 - 56s - loss: 0.0050 - 56s/epoch - 10ms/step
# Epoch 234/250
# 5381/5381 - 71s - loss: 0.0050 - 71s/epoch - 13ms/step
# Epoch 235/250
# 5381/5381 - 21s - loss: 0.0049 - 21s/epoch - 4ms/step
# Epoch 236/250
# 5381/5381 - 21s - loss: 0.0049 - 21s/epoch - 4ms/step
# Epoch 237/250
# 5381/5381 - 21s - loss: 0.0049 - 21s/epoch - 4ms/step
# Epoch 238/250
# 5381/5381 - 21s - loss: 0.0049 - 21s/epoch - 4ms/step
# Epoch 239/250
# 5381/5381 - 21s - loss: 0.0049 - 21s/epoch - 4ms/step
# Epoch 240/250
# 5381/5381 - 21s - loss: 0.0049 - 21s/epoch - 4ms/step
# Epoch 241/250
# 5381/5381 - 25s - loss: 0.0049 - 25s/epoch - 5ms/step
# Epoch 242/250
# 5381/5381 - 24s - loss: 0.0049 - 24s/epoch - 5ms/step
# Epoch 243/250
# 5381/5381 - 25s - loss: 0.0049 - 25s/epoch - 5ms/step
# Epoch 244/250
# 5381/5381 - 25s - loss: 0.0049 - 25s/epoch - 5ms/step
# Epoch 245/250
# 5381/5381 - 66s - loss: 0.0049 - 66s/epoch - 12ms/step
# Epoch 246/250
# 5381/5381 - 70s - loss: 0.0049 - 70s/epoch - 13ms/step
# Epoch 247/250
# 5381/5381 - 23s - loss: 0.0049 - 23s/epoch - 4ms/step
# Epoch 248/250
# 5381/5381 - 22s - loss: 0.0049 - 22s/epoch - 4ms/step
# Epoch 249/250
# 5381/5381 - 24s - loss: 0.0049 - 24s/epoch - 4ms/step
# Epoch 250/250
# 5381/5381 - 33s - loss: 0.0049 - 33s/epoch - 6ms/step

# %%
# evaluate the model
loss = model.evaluate(padded_docs, labels, verbose=2)
print(loss)
# Out:
# 5381/5381 - 12s - loss: 0.0049 - 12s/epoch - 2ms/step
# 0.004895442631095648

# %%
embedding_layer = model.get_layer('embedding')

# %%
embeddings = embedding_layer.get_weights()[0]

# %%
embeddings.shape
# Out:
# (131322, 8)

# %%
type(embeddings)
# Out:
# numpy.ndarray

# %%
np.savetxt("embeddings_model1.csv", embeddings, delimiter=",")
